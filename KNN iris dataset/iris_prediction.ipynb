# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %%
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Type']
data = pd.read_csv("iris.data",names = names)
data.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width         Type
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
plt.figure(figsize=(20,5))
plt.subplot(151)
b1=[]
b2=[]
b3=[]

a1=0;
a2=0;
a3=0;
for i in range(150):
    if (data['Type'][i]=="Iris-setosa"):
        b1.append(data['sepal-length'][i])
        a1=a1+1
    if (data['Type'][i]=="Iris-versicolor"):
        b2.append(data['sepal-length'][i])
        a2=a2+1
    if (data['Type'][i]=="Iris-virginica"):
        b3.append(data['sepal-length'][i])
        a3=a3+1
arr1=np.array(b1) 
arr2=np.array(b2) 
arr3=np.array(b3) 

plt.plot(range(a1),arr1,'ro')
plt.plot(range(a2),arr2,'go')
plt.plot(range(a3),arr3,'bo')


plt.subplot(152)
b11=[]
b21=[]
b31=[]

a11=0;
a21=0;
a31=0;
for i in range(150):
    if (data['Type'][i]=="Iris-setosa"):
        b11.append(data['sepal-width'][i])
        a11=a11+1
    if (data['Type'][i]=="Iris-versicolor"):
        b21.append(data['sepal-width'][i])
        a21=a21+1
    if (data['Type'][i]=="Iris-virginica"):
        b31.append(data['sepal-width'][i])
        a31=a31+1
arr11=np.array(b11) 
arr21=np.array(b21) 
arr31=np.array(b31) 

plt.plot(range(a11),arr11,'ro')
plt.plot(range(a21),arr21,'go')
plt.plot(range(a31),arr31,'bo')


plt.subplot(153)
b12=[]
b22=[]
b32=[]

a12=0;
a22=0;
a32=0;
for i in range(150):
    if (data['Type'][i]=="Iris-setosa"):
        b12.append(data['petal-length'][i])
        a12=a12+1
    if (data['Type'][i]=="Iris-versicolor"):
        b22.append(data['petal-length'][i])
        a22=a22+1
    if (data['Type'][i]=="Iris-virginica"):
        b32.append(data['petal-length'][i])
        a32=a32+1
arr12=np.array(b12) 
arr22=np.array(b22) 
arr32=np.array(b32) 

plt.plot(range(a12),arr12,'ro')
plt.plot(range(a22),arr22,'go')
plt.plot(range(a32),arr32,'bo')



plt.subplot(154)
b13=[]
b23=[]
b33=[]

a13=0;
a23=0;
a33=0;
for i in range(150):
    if (data['Type'][i]=="Iris-setosa"):
        b13.append(data['petal-width'][i])
        a13=a13+1
    if (data['Type'][i]=="Iris-versicolor"):
        b23.append(data['petal-width'][i])
        a23=a23+1
    if (data['Type'][i]=="Iris-virginica"):
        b33.append(data['petal-width'][i])
        a33=a33+1
arr13=np.array(b13) 
arr23=np.array(b23) 
arr33=np.array(b33) 

plt.plot(range(a13),arr13,'ro')
plt.plot(range(a23),arr23,'go')
plt.plot(range(a33),arr33,'bo')


plt.show()

# %%
X = data.iloc[:, :-1].values
y = data.iloc[:, 4].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

algo = KNeighborsClassifier(n_neighbors=5)
algo.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
prediction = algo.predict(X_test)
print(classification_report(y_test, prediction))
print('\nThe accuracy of the KNN Algoritham is',metrics.accuracy_score(y_test, prediction))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         7
# Iris-versicolor       1.00      1.00      1.00        12
#  Iris-virginica       1.00      1.00      1.00        11
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
#
#
# The accuracy of the KNN Algoritham is 1.0
